# %% [markdown]
# # Se visualiza el excel que se llama concentrado
#
# Queria saber por que habia ids duplicados. Hay 3689 ids duplicados.
# No salgo en el concentrado, pero si en el de `Asesorias2024` y en `dev` en la hoja de Asesorias.

# %%
from scripts import rexcel 

df = rexcel.read_concentrado()

# %%
import pandas as pd
pd.set_option('display.max_columns', None)

# %%
print(df.shape)
df.head()
# Out:
# (5000, 22)
#        ID Carrera    Materia Clave materia Periodo (Prim_Ot)  \
# 0  159060     LIM  Cálculo I       MAT1022             OTOÑO
# 1  159685     LEC  Cálculo I       MAT1022             OTOÑO
# 2  160235     BNI  Cálculo I       MAT1022             OTOÑO
# 3  160235     BNI  Cálculo I       MAT1022             OTOÑO
# 4  160235     BNI  Cálculo I       MAT1022             OTOÑO
#
#    Profesor de materia Tomó asesoría (Sí/No)  \
# 0              22471.0                    Sí
# 1              23852.0                    Sí
# 2              22521.0                    Sí
# 3              22521.0                    Sí
# 4              22521.0                    Sí
#
#    Número de asesorías registradas (por materia)  \
# 0                                              1
# 1                                              1
# 2                                              3
# 3                                              3
# 4                                              3
#
# ...

# %%
dfi = df.set_index(['ID'])
print(dfi.shape)
dfi
# Out:
# (5000, 21)
#        Carrera         Materia Clave materia Periodo (Prim_Ot)  \
# ID
# 159060     LIM       Cálculo I       MAT1022             OTOÑO
# 159685     LEC       Cálculo I       MAT1022             OTOÑO
# 160235     BNI       Cálculo I       MAT1022             OTOÑO
# 160235     BNI       Cálculo I       MAT1022             OTOÑO
# 160235     BNI       Cálculo I       MAT1022             OTOÑO
# ...        ...             ...           ...               ...
# 181849     LCS  Álgebra Lineal       MAT1032         PRIMAVERA
# 181849     LCS  Álgebra Lineal       MAT1032         PRIMAVERA
# 182177     LII  Álgebra Lineal       MAT1032         PRIMAVERA
# 182518     LBN  Álgebra Lineal       MAT1032         PRIMAVERA
# 182674     LIC  Álgebra Lineal       MAT1032         PRIMAVERA
#
#         Profesor de materia Tomó asesoría (Sí/No)  \
# ID
# 159060              22471.0                    Sí
# 159685              23852.0                    Sí
# ...

# %%
# are there duplicated IDs?
dfi.index.duplicated().sum()
# Out:
# np.int64(3689)

# %% [markdown]
# # Hay 3689 duplicados

# %%
# display the duplicated IDs
dfi[dfi.index.duplicated(keep=False)].sort_index()
# Out:
#        Carrera                              Materia Clave materia  \
# ID
# 92988      LPA  Estadística Para Ciencias Sociales        MAT1052
# 92988      LPA  Estadística Para Ciencias Sociales        MAT1052
# 92988      LPA  Estadística Para Ciencias Sociales        MAT1052
# 159491     LRM  Estadística Para Ciencias Sociales        MAT1052
# 159491     LRM  Estadística Para Ciencias Sociales        MAT1052
# ...        ...                                  ...           ...
# 182682     LII                            Cálculo I       MAT1022
# 182682     LII                            Cálculo I       MAT1022
# 182682     LII                            Cálculo I       MAT1022
# 183549     LMK          Matemáticas Universitarias        MAT1012
# 183549     LMK          Matemáticas Universitarias        MAT1012
#
#        Periodo (Prim_Ot)  Profesor de materia Tomó asesoría (Sí/No)  \
# ID
# 92988              OTOÑO              21815.0                    Sí
# ...

# %%
# view the index 183549
dfi.loc[183549]
# Out:
#        Carrera                      Materia Clave materia Periodo (Prim_Ot)  \
# ID
# 183549     LMK  Matemáticas Universitarias        MAT1012         PRIMAVERA
# 183549     LMK  Matemáticas Universitarias        MAT1012         PRIMAVERA
#
#         Profesor de materia Tomó asesoría (Sí/No)  \
# ID
# 183549              23434.0                    Sí
# 183549              23434.0                    Sí
#
#         Número de asesorías registradas (por materia)  \
# ID
# 183549                                              2
# 183549                                              2
#
#         Número de asesorías registradas (por materia y tema)  \
# ID
# 183549                                                  1
# 183549                                                  1
#
#         Número de asesorías registradas (por materia, tema y profesor)  \
# ID
# 183549                                                  1
# 183549                                                  1
#
# ...

# %%
df.loc[175199]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\herie\miniconda3\envs\a\Lib\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 175199 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 df.loc[175199]
#
# File c:\Users\herie\miniconda3\envs\a\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %% [markdown]
# # Por que no salgo en el concentrado?

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df.loc[178025]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\herie\miniconda3\envs\a\Lib\site-packages\pandas\core\indexes\range.py:413, in RangeIndex.get_loc(self, key)
#     412 try:
# --> 413     return self._range.index(new_key)
#     414 except ValueError as err:
#
# ValueError: 178025 is not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 df.loc[178025]
#
# File c:\Users\herie\miniconda3\envs\a\Lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Estoy en el Excel de Asesorias pero no estoy en el de Concentrado

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Tambien estoy en dev

# %% [markdown]
# <!-- # Por que no salgo en el concentrado?
